# %%
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#loading the data
df = pd.read_csv("sales.csv", encoding = "ISO-8859-10")

# %%
df
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
#                 State      Zone       Occupation Product_Category  Orders  \
# 0         Maharashtra   Western       Healthcare             Auto       1
# 1      Andhra Pradesh  Southern             Govt             Auto       3
# 2       Uttar Pradesh   Central       Automobile             Auto       3
# 3           Karnataka  Southern     Construction             Auto       2
# 4             Gujarat   Western  Food Processing             Auto       2
# ...               ...       ...              ...              ...     ...
# 11246     Maharashtra   Western         Chemical           Office       4
# 11247         Haryana  Northern       Healthcare       Veterinary       3
# 11248  Madhya Pradesh   Central          Textile           Office       4
# 11249       Karnataka  Southern      Agriculture           Office       3
# 11250     Maharashtra   Western       Healthcare           Office       3
#
#         Amount  Status  unnamed1
# 0      23952.0     NaN       NaN
# 1      23934.0     NaN       NaN
# 2      23924.0     NaN       NaN
# 3      23912.0     NaN       NaN
# 4      23877.0     NaN       NaN
# ...        ...     ...       ...
# 11246    370.0     NaN       NaN
# 11247    367.0     NaN       NaN
# 11248    213.0     NaN       NaN
# 11249    206.0     NaN       NaN
# 11250    188.0     NaN       NaN
#
# [11251 rows x 15 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %%
#fetching the null values
df[df["Amount"].isnull()]
# Out:
#      User_ID Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 7    1002092  Shivangi  P00273442      F       55+   61               0
# 14   1003858      Cano  P00293742      M     46-50   46               1
# 16   1005447       Amy  P00275642      F     46-50   48               1
# 109  1005265    Sakshi  P00296242      F     46-50   48               1
# 111  1005261   Apoorva  P00057942      F     36-45   41               1
# 184  1005538    Kartik  P00269542      F     46-50   49               1
# 293  1000326  Jonathan  P00120542      M     51-55   53               0
# 344  1002507   Lakshmi  P00045842      F     26-35   35               1
# 345  1004498   Srishti  P00030842      F     51-55   55               0
# 452  1004601    Gaurav  P00014442      F     36-45   40               1
# 464  1004528    Anurag  P00338442      F     26-35   33               1
# 493  1002994    Hemant   P0009942      F     36-45   38               0
#
#               State      Zone   Occupation  Product_Category  Orders  Amount  \
# 7       Maharashtra   Western    IT Sector              Auto       1     NaN
# 14   Madhya Pradesh   Central  Hospitality              Auto       3     NaN
# 16   Andhra Pradesh  Southern    IT Sector              Auto       3     NaN
# 109           Delhi   Central      Banking  Footwear & Shoes       1     NaN
# 111           Delhi   Central    IT Sector  Footwear & Shoes       2     NaN
# 184       Karnataka  Southern      Banking  Footwear & Shoes       1     NaN
# 293         Gujarat   Western    IT Sector  Footwear & Shoes       3     NaN
# 344         Gujarat   Western     Chemical         Furniture       1     NaN
# 345           Delhi   Central      Textile  Footwear & Shoes       1     NaN
# 452  Madhya Pradesh   Central  Hospitality              Food       4     NaN
# 464   Uttar Pradesh   Central   Automobile              Food       2     NaN
# 493   Uttar Pradesh   Central    IT Sector              Food       4     NaN
#
#      Status  unnamed1
# 7       NaN       NaN
# 14      NaN       NaN
# 16      NaN       NaN
# 109     NaN       NaN
# 111     NaN       NaN
# 184     NaN       NaN
# 293     NaN       NaN
# 344     NaN       NaN
# 345     NaN       NaN
# 452     NaN       NaN
# 464     NaN       NaN
# 493     NaN       NaN

# %%
#removing duplicates from the data
df.drop_duplicates(inplace = True)

# %%
df
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
#                 State      Zone       Occupation Product_Category  Orders  \
# 0         Maharashtra   Western       Healthcare             Auto       1
# 1      Andhra Pradesh  Southern             Govt             Auto       3
# 2       Uttar Pradesh   Central       Automobile             Auto       3
# 3           Karnataka  Southern     Construction             Auto       2
# 4             Gujarat   Western  Food Processing             Auto       2
# ...               ...       ...              ...              ...     ...
# 11246     Maharashtra   Western         Chemical           Office       4
# 11247         Haryana  Northern       Healthcare       Veterinary       3
# 11248  Madhya Pradesh   Central          Textile           Office       4
# 11249       Karnataka  Southern      Agriculture           Office       3
# 11250     Maharashtra   Western       Healthcare           Office       3
#
#         Amount  Status  unnamed1
# 0      23952.0     NaN       NaN
# 1      23934.0     NaN       NaN
# 2      23924.0     NaN       NaN
# 3      23912.0     NaN       NaN
# 4      23877.0     NaN       NaN
# ...        ...     ...       ...
# 11246    370.0     NaN       NaN
# 11247    367.0     NaN       NaN
# 11248    213.0     NaN       NaN
# 11249    206.0     NaN       NaN
# 11250    188.0     NaN       NaN
#
# [11243 rows x 15 columns]

# %%
#droping the columns named ---> status and unnamed1
df = df.drop(["Status","unnamed1"],axis = 1)

# %%
df
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
#                 State      Zone       Occupation Product_Category  Orders  \
# 0         Maharashtra   Western       Healthcare             Auto       1
# 1      Andhra Pradesh  Southern             Govt             Auto       3
# 2       Uttar Pradesh   Central       Automobile             Auto       3
# 3           Karnataka  Southern     Construction             Auto       2
# 4             Gujarat   Western  Food Processing             Auto       2
# ...               ...       ...              ...              ...     ...
# 11246     Maharashtra   Western         Chemical           Office       4
# 11247         Haryana  Northern       Healthcare       Veterinary       3
# 11248  Madhya Pradesh   Central          Textile           Office       4
# 11249       Karnataka  Southern      Agriculture           Office       3
# 11250     Maharashtra   Western       Healthcare           Office       3
#
#         Amount
# 0      23952.0
# 1      23934.0
# 2      23924.0
# 3      23912.0
# 4      23877.0
# ...        ...
# 11246    370.0
# 11247    367.0
# 11248    213.0
# 11249    206.0
# 11250    188.0
#
# [11243 rows x 13 columns]

# %%
#droping the null values from the data
df.dropna(inplace = True)

# %%
#rename the column name "Marital_Status" to 'Marital'
df.rename(columns = {"Marital_Status":'Marital'},inplace =True)

# %%
df['Marital'].unique()
# Out:
# array([0, 1])

# %%
#change the values of Marital col 0-->single, 1--> married
df["Marital"] = df['Marital'].map({0:"Single",1:"Married"})

# %%
# change the values of Gender col F-->Female, M-->Male
df["Gender"] = df["Gender"].map({'F':"Female",'M':'Male'})

# %%
  df
# Out:
#        User_ID    Cust_name Product_ID  Gender Age Group  Age  Marital  \
# 0      1002903    Sanskriti  P00125942  Female     26-35   28   Single
# 1      1000732       Kartik  P00110942  Female     26-35   35  Married
# 2      1001990        Bindu  P00118542  Female     26-35   35  Married
# 3      1001425       Sudevi  P00237842    Male      0-17   16   Single
# 4      1000588         Joni  P00057942    Male     26-35   28  Married
# ...        ...          ...        ...     ...       ...  ...      ...
# 11246  1000695      Manning  P00296942    Male     18-25   19  Married
# 11247  1004089  Reichenbach  P00171342    Male     26-35   33   Single
# 11248  1001209        Oshin  P00201342  Female     36-45   40   Single
# 11249  1004023       Noonan  P00059442    Male     36-45   37   Single
# 11250  1002744      Brumley  P00281742  Female     18-25   19   Single
#
#                 State      Zone       Occupation Product_Category  Orders  \
# 0         Maharashtra   Western       Healthcare             Auto       1
# 1      Andhra Pradesh  Southern             Govt             Auto       3
# 2       Uttar Pradesh   Central       Automobile             Auto       3
# 3           Karnataka  Southern     Construction             Auto       2
# 4             Gujarat   Western  Food Processing             Auto       2
# ...               ...       ...              ...              ...     ...
# 11246     Maharashtra   Western         Chemical           Office       4
# 11247         Haryana  Northern       Healthcare       Veterinary       3
# 11248  Madhya Pradesh   Central          Textile           Office       4
# 11249       Karnataka  Southern      Agriculture           Office       3
# 11250     Maharashtra   Western       Healthcare           Office       3
#
#         Amount
# 0      23952.0
# 1      23934.0
# 2      23924.0
# 3      23912.0
# 4      23877.0
# ...        ...
# 11246    370.0
# 11247    367.0
# 11248    213.0
# 11249    206.0
# 11250    188.0
#
# [11231 rows x 13 columns]

# %%
df.reset_index(inplace = True)

# %%
df.drop(["index"],axis = 1)
# Out:
#        User_ID    Cust_name Product_ID  Gender Age Group  Age  Marital  \
# 0      1002903    Sanskriti  P00125942  Female     26-35   28   Single
# 1      1000732       Kartik  P00110942  Female     26-35   35  Married
# 2      1001990        Bindu  P00118542  Female     26-35   35  Married
# 3      1001425       Sudevi  P00237842    Male      0-17   16   Single
# 4      1000588         Joni  P00057942    Male     26-35   28  Married
# ...        ...          ...        ...     ...       ...  ...      ...
# 11226  1000695      Manning  P00296942    Male     18-25   19  Married
# 11227  1004089  Reichenbach  P00171342    Male     26-35   33   Single
# 11228  1001209        Oshin  P00201342  Female     36-45   40   Single
# 11229  1004023       Noonan  P00059442    Male     36-45   37   Single
# 11230  1002744      Brumley  P00281742  Female     18-25   19   Single
#
#                 State      Zone       Occupation Product_Category  Orders  \
# 0         Maharashtra   Western       Healthcare             Auto       1
# 1      Andhra Pradesh  Southern             Govt             Auto       3
# 2       Uttar Pradesh   Central       Automobile             Auto       3
# 3           Karnataka  Southern     Construction             Auto       2
# 4             Gujarat   Western  Food Processing             Auto       2
# ...               ...       ...              ...              ...     ...
# 11226     Maharashtra   Western         Chemical           Office       4
# 11227         Haryana  Northern       Healthcare       Veterinary       3
# 11228  Madhya Pradesh   Central          Textile           Office       4
# 11229       Karnataka  Southern      Agriculture           Office       3
# 11230     Maharashtra   Western       Healthcare           Office       3
#
#         Amount
# 0      23952.0
# 1      23934.0
# 2      23924.0
# 3      23912.0
# 4      23877.0
# ...        ...
# 11226    370.0
# 11227    367.0
# 11228    213.0
# 11229    206.0
# 11230    188.0
#
# [11231 rows x 13 columns]

# %%
df.drop(["index"],axis = 1,inplace = True)

# %%
df
# Out:
#        User_ID    Cust_name Product_ID  Gender Age Group  Age  Marital  \
# 0      1002903    Sanskriti  P00125942  Female     26-35   28   Single
# 1      1000732       Kartik  P00110942  Female     26-35   35  Married
# 2      1001990        Bindu  P00118542  Female     26-35   35  Married
# 3      1001425       Sudevi  P00237842    Male      0-17   16   Single
# 4      1000588         Joni  P00057942    Male     26-35   28  Married
# ...        ...          ...        ...     ...       ...  ...      ...
# 11226  1000695      Manning  P00296942    Male     18-25   19  Married
# 11227  1004089  Reichenbach  P00171342    Male     26-35   33   Single
# 11228  1001209        Oshin  P00201342  Female     36-45   40   Single
# 11229  1004023       Noonan  P00059442    Male     36-45   37   Single
# 11230  1002744      Brumley  P00281742  Female     18-25   19   Single
#
#                 State      Zone       Occupation Product_Category  Orders  \
# 0         Maharashtra   Western       Healthcare             Auto       1
# 1      Andhra Pradesh  Southern             Govt             Auto       3
# 2       Uttar Pradesh   Central       Automobile             Auto       3
# 3           Karnataka  Southern     Construction             Auto       2
# 4             Gujarat   Western  Food Processing             Auto       2
# ...               ...       ...              ...              ...     ...
# 11226     Maharashtra   Western         Chemical           Office       4
# 11227         Haryana  Northern       Healthcare       Veterinary       3
# 11228  Madhya Pradesh   Central          Textile           Office       4
# 11229       Karnataka  Southern      Agriculture           Office       3
# 11230     Maharashtra   Western       Healthcare           Office       3
#
#         Amount
# 0      23952.0
# 1      23934.0
# 2      23924.0
# 3      23912.0
# 4      23877.0
# ...        ...
# 11226    370.0
# 11227    367.0
# 11228    213.0
# 11229    206.0
# 11230    188.0
#
# [11231 rows x 13 columns]

# %%
#visualization of data|

# %%
a = sns.countplot(x="Gender", data=df, palette = ['#08306B', '#C6DBEF'],edgecolor = "black"

)

for i in a.containers:
    a.bar_label(i, weight="bold", fontsize=10)

plt.title("Gender_count",fontsize = 14,weight = "bold")
plt.xlabel("Gender", fontsize=14)
plt.ylabel("Count", fontsize=14)

a.set_xticklabels(a.get_xticklabels(), fontsize=10)

plt.show()
# Out:
# /tmp/ipython-input-48-3978414673.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   a = sns.countplot(x="Gender", data=df, palette = ['#08306B', '#C6DBEF'],edgecolor = "black"
# /tmp/ipython-input-48-3978414673.py:12: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   a.set_xticklabels(a.get_xticklabels(), fontsize=10)

# %%
#which age group spends more

df.groupby("Age Group")["Amount"].sum().sort_values()
# Out:
# Age Group
# 0-17      2699653.00
# 55+       4080987.00
# 51-55     8237909.00
# 46-50     9207844.00
# 18-25    17235530.00
# 36-45    22135136.49
# 26-35    42581768.94
# Name: Amount, dtype: float64

# %%
plt.figure(figsize = (10,5))
high = df.groupby("Age Group",as_index=False)["Amount"].sum().sort_values(by="Amount",ascending=False)
b = sns.barplot(x = 'Age Group',y = "Amount",data = high, palette = palette_14,edgecolor = "black")

for i in b.containers:
  b.bar_label(i,padding = 23)

plt.xlabel ("Age Group",fontsize = 12)
plt.ylabel ("Amount",fontsize = 12)
plt.title ("Amount vs Age Group",fontsize = 14,weight = "bold")
plt.tight_layout()
sns.despine()
plt.show()
# Out:
# /tmp/ipython-input-50-4283175735.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   b = sns.barplot(x = 'Age Group',y = "Amount",data = high, palette = palette_14,edgecolor = "black")
# /tmp/ipython-input-50-4283175735.py:3: UserWarning: The palette list has more values (15) than needed (7), which may not be intended.
#   b = sns.barplot(x = 'Age Group',y = "Amount",data = high, palette = palette_14,edgecolor = "black")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11231 entries, 0 to 11230
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11231 non-null  int64
#  1   Cust_name         11231 non-null  object
#  2   Product_ID        11231 non-null  object
#  3   Gender            11231 non-null  object
#  4   Age Group         11231 non-null  object
#  5   Age               11231 non-null  int64
#  6   Marital           11231 non-null  object
#  7   State             11231 non-null  object
#  8   Zone              11231 non-null  object
#  9   Occupation        11231 non-null  object
#  10  Product_Category  11231 non-null  object
#  11  Orders            11231 non-null  int64
#  12  Amount            11231 non-null  float64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 1.1+ MB

# %%
# Finding which gender spends
df.groupby("Gender")["Amount"].sum().sort_values().tail(1)
#ans ---- females
# Out:
# Gender
# Female    74307682.43
# Name: Amount, dtype: float64

# %%
high = df.groupby("Gender",as_index=False)["Amount"].sum().sort_values(by = "Amount",ascending=False)
a = sns.barplot(x ="Gender",y ="Amount",data = high,palette =['#08306B', '#C6DBEF'],edgecolor = "black")
for i in a.containers:
  a.bar_label(i)

plt.title("Gender vs Amount",fontsize = 10,weight = "bold")
plt.xlabel("Gender",fontsize = 12)
plt.ylabel("Amount",fontsize = 12)

plt.tight_layout()

plt.show()
# Out:
# /tmp/ipython-input-54-316504379.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   a = sns.barplot(x ="Gender",y ="Amount",data = high,palette =['#08306B', '#C6DBEF'],edgecolor = "black")

# %%
# Which states recorded the highest spending?
df.groupby("State")["Amount"].sum().sort_values()
#ans ---- > Uttar Pradesh
# Out:
# State
# Telangana            1151490.00
# Punjab               1525800.00
# Rajasthan            1909409.00
# Uttarakhand          2520944.00
# Jharkhand            3026456.00
# Kerala               3894491.99
# Gujarat              3938159.00
# Bihar                4014669.00
# Haryana              4217871.00
# Himachal Pradesh     4963368.00
# Andhra Pradesh       8037146.99
# Madhya Pradesh       8101142.00
# Delhi               11603819.45
# Karnataka           13523540.00
# Maharashtra         14404467.00
# Uttar Pradesh       19346055.00
# Name: Amount, dtype: float64

# %%
#state which spends most
top_states = df.groupby("State", as_index=False)["Amount"].sum().sort_values(by="Amount", ascending=False)

plt.figure(figsize=(17, 10))
palette_14 = sns.color_palette("Blues", 16)[::-1]
a = sns.barplot(x="State", y="Amount", data=top_states,palette = palette_14,edgecolor = "black")

for container in a.containers:
    a.bar_label(container, padding=3)

plt.xticks(rotation=90)
plt.title("Total Spending by States", fontsize=16,weight = "bold")
plt.xlabel("States", fontsize=16)
plt.ylabel("Amount", fontsize=16)

plt.tight_layout()
sns.despine()
plt.show()
# Out:
# /tmp/ipython-input-56-2869564163.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   a = sns.barplot(x="State", y="Amount", data=top_states,palette = palette_14,edgecolor = "black")

# %%
# Which Product Categories has the highest spending?
df.groupby("Product_Category")["Amount"].sum().sort_values().tail(1)
#Food
# Out:
# Product_Category
# Food    33933883.5
# Name: Amount, dtype: float64

# %%
plt.figure(figsize=(26,13))
high = df.groupby("Product_Category",as_index=False)["Amount"].sum().sort_values(by = "Amount",ascending = False)
palette_14 = sns.color_palette("Blues", 18)[::-1]
a = sns.barplot(x = "Product_Category",y = "Amount",data = high, palette = palette_14,edgecolor = "black" )
for i in a.containers:
  a.bar_label(i)

plt.xticks(rotation=90)
plt.title("most selled product", fontsize=20,weight = "bold")
plt.xlabel("Product", fontsize=20)
plt.ylabel("Amount", fontsize=20)

plt.xticks(fontsize=15)
plt.yticks(fontsize=15)

plt.tight_layout()
sns.despine()
plt.show()
# Out:
# /tmp/ipython-input-58-588289282.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   a = sns.barplot(x = "Product_Category",y = "Amount",data = high, palette = palette_14,edgecolor = "black" )

# %%
# Which Occupation group spent the most?
df.groupby("Occupation")["Amount"].sum().sort_values().tail(1)
#IT Sector
# Out:
# Occupation
# IT Sector    14741862.0
# Name: Amount, dtype: float64

# %%
plt.figure(figsize=(20, 10))

high = df.groupby("Occupation", as_index = False)["Amount"].sum().sort_values(by="Amount", ascending=False)

palette_14 = sns.color_palette("Blues", 15)[::-1]

b = sns.barplot(x='Occupation', y='Amount', data=high, palette=palette_14,edgecolor = "black")

for i in b.containers:
    b.bar_label(i, padding=23)

plt.xlabel("Occupation", fontsize=15)
plt.ylabel("Total Spending", fontsize=15)
plt.title("Top Occupations by Total Spending", fontsize=15, weight="bold")

plt.tight_layout()
sns.despine()
plt.show()
# Out:
# /tmp/ipython-input-60-1168051150.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   b = sns.barplot(x='Occupation', y='Amount', data=high, palette=palette_14,edgecolor = "black")

# %%
# Married or single who spends more?
df.groupby("Marital")["Amount"].sum().sort_values().tail(1)
#singles spend more
# Out:
# Marital
# Single    62098736.44
# Name: Amount, dtype: float64

# %%
plt.figure(figsize = (10,5))
#high = df.groupby("Marital",as_index=False)["Amount"].sum().sort_values(by="Amount",ascending=False)
#b = sns.barplot(x = 'Marital',y = "Amount",data = high, palette = ['#08306B', '#C6DBEF'],estimator = np.sum,edgecolor = "black")
b = sns.barplot(x='Marital', y='Amount', data=df.groupby('Marital', as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False), palette=['#08306B', '#C6DBEF'], estimator=np.sum, edgecolor='black')

for i in b.containers:
  b.bar_label(i, label_type='center', color='white', fontsize=12, weight='bold')

plt.xlabel ("marital status",fontsize = 15)
plt.ylabel ("Amount",fontsize = 15)
plt.title ("How Married vs Unmarried Spend",fontsize = 15,weight = "bold")
plt.tight_layout()
sns.despine()
plt.show()
# Out:
# /tmp/ipython-input-62-834562307.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   b = sns.barplot(x='Marital', y='Amount', data=df.groupby('Marital', as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False), palette=['#08306B', '#C6DBEF'], estimator=np.sum, edgecolor='black')

# %%
from IPython.display import display, HTML

html_form = """
<div style="font-family: Arial; padding: 20px; border: 2px solid #000000; border-radius: 10px; background-color: #ffffff; color: #000000; width: 90%">
  <h2 style="color: #000000;"> Consumer Spending Analysis Form</h2>

  <p><strong>1. Gender Distribution:</strong> Female customers dominate with a count of 7,828, nearly double that of males (3,403).</p>
  <p><strong>2. Gender Spending Trend:</strong> Women outspend men, indicating stronger purchasing power or intent.</p>
  <p><strong>3. Top Spending Age Group:</strong> 26–35 years — likely due to stable income and fewer responsibilities.</p>
  <p><strong>4. Top Spending State:</strong> Uttar Pradesh — shows strong market presence or brand reach.</p>
  <p><strong>5. Highest Spending Category:</strong> Food Products — suggests essential or habitual consumption.</p>
  <p><strong>6. Leading Contributing Industry:</strong> IT Sector — tech professionals appear more willing or able to spend.</p>
  <p><strong>7. Marital Status Spending Trend:</strong> Singles spend more than married individuals — possibly due to fewer financial constraints.</p>
</div>
"""

display(HTML(html_form))
# Out:
# <div style="font-family: Arial; padding: 20px; border: 2px solid #000000; border-radius: 10px; background-color: #ffffff; color: #000000; width: 90%">
#   <h2 style="color: #000000;"> Consumer Spending Analysis Form</h2>
#
#   <p><strong>1. Gender Distribution:</strong> Female customers dominate with a count of 7,828, nearly double that of males (3,403).</p>
#   <p><strong>2. Gender Spending Trend:</strong> Women outspend men, indicating stronger purchasing power or intent.</p>
#   <p><strong>3. Top Spending Age Group:</strong> 26–35 years — likely due to stable income and fewer responsibilities.</p>
#   <p><strong>4. Top Spending State:</strong> Uttar Pradesh — shows strong market presence or brand reach.</p>
#   <p><strong>5. Highest Spending Category:</strong> Food Products — suggests essential or habitual consumption.</p>
#   <p><strong>6. Leading Contributing Industry:</strong> IT Sector — tech professionals appear more willing or able to spend.</p>
#   <p><strong>7. Marital Status Spending Trend:</strong> Singles spend more than married individuals — possibly due to fewer financial constraints.</p>
# </div>
